# %%
import main as pyFile

df = pyFile.fetchData()

df.to_csv('mental_health_normalised_data.csv', index=False)

# %%
# Out:
#       EmpID  Age  GenderCode  AgeRange  CountryID     NoEmployees  \
# 0         1   37           1         2         46            6-25
# 1         2   44           0         2         46  More than 1000
# 2         3   32           0         2          8            6-25
# 3         4   31           0         2         45          26-100
# 4         5   31           0         2         46         100-500
# ...     ...  ...         ...       ...        ...             ...
# 1254   1255   26           0         1         45          26-100
# 1255   1256   32           0         2         46          26-100
# 1256   1257   34           0         2         46  More than 1000
# 1257   1258   46           1         2         46         100-500
# 1258   1259   25           0         1         46          26-100
#
#       NoEmployeesRange SelfEmployed FamilyHistory Treatment  ...   Anonymous  \
# 0                    1         None            No       Yes  ...         Yes
# ...
